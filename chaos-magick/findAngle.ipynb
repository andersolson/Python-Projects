# %%
import math

# %%
startX = 4
startY = 5

# %%
endX = 10
endY = -1

# %%
myradians = math.atan2(endY-startY, endX-startX)
myradians
# Out:
# -0.7853981633974483

# %%
mydegrees = math.degrees(myradians)
mydegrees
# Out:
# -45.0

# %%
import matplotlib.pyplot as plt

# %%
x = [4, 10]
y = [5,-1]

# %%
plt.plot(x,y,'->')
plt.axis('equal')
plt.show()

# %%
from matplotlib.markers import MarkerStyle

# %%
m = MarkerStyle('>')
m._transform.rotate_deg(-45)

# %%
plt.plot(x,y)
plt.axis('equal')
plt.show()

# %%
plt.plot(x,y)
plt.scatter(x,y, s=200, marker=m, color="crimson")
plt.axis('equal')
plt.show()

# %%
m = MarkerStyle('>')
m._transform.rotate_deg(mydegrees)


plt.plot(x,y)
plt.scatter(x,y, s=200, marker=m, color="crimson")
plt.axis('equal')
plt.show()

# %%
startX = 1
startY = 2

endX = 3
endY = 1

myradians = math.atan2(endY-startY, endX-startX)
myradians
# Out:
# -0.4636476090008061

# %%
mydegrees = math.degrees(myradians)
mydegrees
# Out:
# -26.56505117707799

# %%
m = MarkerStyle('>')
m._transform.rotate_deg(mydegrees)

x = [1,3]
y = [2,1]

plt.plot(x,y)
plt.scatter(x,y, s=200, marker=m, color="crimson")
plt.axis('equal')
plt.show()
