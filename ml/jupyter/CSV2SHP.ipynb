# %%
import geopandas as gpd
import pandas as pd

# %%
csvPath = r'D:\Projects\Github\SAGIS-Users\anderso\FirebreakEnhancement\data\CO_Agriculture_testpoints.csv'

gdfCSV = gpd.read_file(csvPath)

gdfCSV
# Out:
#    FID   BREAK_NAME      POINT_X     POINT_Y geometry
# 0    0  Agriculture  -102.844223   40.835578     None
# 1    1  Agriculture  -103.566213  40.6053415     None
# 2    2  Agriculture  -104.092567  37.0110535     None
# 3    3  Agriculture  -102.350475   38.176128     None
# 4    4  Agriculture  -103.058491  40.3426545     None
# ..  ..          ...          ...         ...      ...
# 65  65  Agriculture  -102.783669   37.176891     None
# 66  66  Agriculture  -107.944733  40.4609205     None
# 67  67  Agriculture  -103.207547   38.050928     None
# 68  68  Agriculture  -103.165625  40.8132615     None
# 69  69  Agriculture  -103.133019  38.1940315     None
#
# [70 rows x 5 columns]

# %%
#geometry = gpd.points_from_xy(gdfCSV.POINT_X, gdfCSV.POINT_Y, crs="EPSG:4326")

gdfPoints = gpd.GeoDataFrame(gdfCSV, geometry=gpd.points_from_xy(gdfCSV.POINT_X, gdfCSV.POINT_Y, crs="EPSG:4326"))

gdfPoints
# Out:
# C:\Users\andolson\anaconda3\envs\mlai\lib\site-packages\geopandas\array.py:275: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   return GeometryArray(vectorized.points_from_xy(x, y, z), crs=crs)
#    FID   BREAK_NAME      POINT_X     POINT_Y                     geometry
# 0    0  Agriculture  -102.844223   40.835578  POINT (-102.84422 40.83558)
# 1    1  Agriculture  -103.566213  40.6053415  POINT (-103.56621 40.60534)
# 2    2  Agriculture  -104.092567  37.0110535  POINT (-104.09257 37.01105)
# 3    3  Agriculture  -102.350475   38.176128  POINT (-102.35048 38.17613)
# 4    4  Agriculture  -103.058491  40.3426545  POINT (-103.05849 40.34265)
# ..  ..          ...          ...         ...                          ...
# 65  65  Agriculture  -102.783669   37.176891  POINT (-102.78367 37.17689)
# 66  66  Agriculture  -107.944733  40.4609205  POINT (-107.94473 40.46092)
# ...

# %%
gdfPoints.plot()
# Out:
# <AxesSubplot: >

# %%
pnts = r'D:\Projects\Github\SAGIS-Users\anderso\FirebreakEnhancement\data\Internal\test.shp'

gdfPoints.to_file(pnts)
# Out:
# C:\Users\andolson\anaconda3\envs\mlai\lib\site-packages\geopandas\io\file.py:299: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
